# %%
# show all columns
pd.set_option('display.max_columns', None)

# %% [markdown]
# Brazil 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/brazil-2019'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text)
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text)
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text)
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text)
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text)


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
def check_in_category(category, key):
    if key in category:
        index = category.index(key)
        return index
    else:
        return -1

# %%
farm_url[0]

# %%
farm_page = requests.get("https://allianceforcoffeeexcellence.org/directory/92-23/")
farm_root = BeautifulSoup(farm_page.content, 'html.parser')
all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
all_cat = [cat.text.strip() for cat in all_cat]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Brazil_2019.csv", index=False)

# %% [markdown]
# Brazil 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/brazil-2021'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1640023456252-075acb18-b088").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text)
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text)
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text)
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text)
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text)


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
def check_in_category(category, key):
    if key in category:
        index = category.index(key)
        return index
    else:
        return -1

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df

# %%
df.to_csv("Brazil_2021.csv", index=False)

# %% [markdown]
# Brazil 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/brazil-2022'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    col_dict['coe_score'].append(tmp[2].text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].text.strip())
    col_dict['high_bid'].append(tmp[4].text.strip())
    col_dict['total_value'].append(tmp[5].text.strip())
    col_dict['company'].append(tmp[6].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
def check_in_category(category, key):
    if key in category:
        index = category.index(key)
        return index
    else:
        return -1

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df

# %%
df.to_csv("Brazil_2022.csv", index=False)

# %% [markdown]
# Bolivia 2004

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/bolivia-2004/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_url[0]

# %%
farm_page = requests.get("https://allianceforcoffeeexcellence.org/farm-directory/90-44/")
farm_root = BeautifulSoup(farm_page.content, 'html.parser')
all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
all_cat = [cat.text.strip() for cat in all_cat]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Bolivia_2004.csv", index=False)

# %% [markdown]
# Bolivia 2005

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/bolivia-2005/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Bolivia_2005.csv", index=False)

# %% [markdown]
# Bolivia 2007

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/bolivia-2007/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Bolivia_2007.csv", index=False)

# %% [markdown]
# Bolivia 2008

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/bolivia-2008/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Bolivia_2008.csv", index=False)

# %% [markdown]
# Bolivia 2009

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/bolivia-2009/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Bolivia_2009.csv", index=False)

# %% [markdown]
# Burundi 2013

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2013/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df.to_csv("Burundi_2013.csv", index=False)

# %% [markdown]
# Burundi 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df.to_csv("Burundi_2014.csv", index=False)

# %% [markdown]
# Burundi 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df.to_csv("Burundi_2015.csv", index=False)

# %% [markdown]
# Burundi 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df.to_csv("Burundi_2017.csv", index=False)

# %% [markdown]
# Burundi 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1538505057050-ed3488f6-00d5").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-2):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[7].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    farm_url.append(tmp_2[6].find("a").get("href"))

# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Burundi_2018.csv", index=False)

# %% [markdown]
# Burundi_2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/burundi-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text)
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text)
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text)
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text)
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text)


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)-3):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Burundi_2019.csv", index=False)

# %% [markdown]
# Colombia South 2012

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-south-2012/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2012.csv", index=False)

# %% [markdown]
# Colombia North 2013

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-north-2013'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2013.csv", index=False)

# %% [markdown]
# Colombia South 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-south-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2014.csv", index=False)

# %% [markdown]
# Colombia North 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-north-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2015.csv", index=False)

# %% [markdown]
# Colombia North 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2017.csv", index=False)

# %% [markdown]
# Colombia 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1532451068017-63a2021a-1ec4").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    # col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2018.csv", index=False)

# %% [markdown]
# Colombia 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-north-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find_all("table", class_="mtr-table mtr-tr-td")[2].find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    # col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2019.csv", index=False)

# %% [markdown]
# Colombia 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/colombia-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Colombia_2020.csv", index=False)

# %% [markdown]
# Colombia 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel",  id="1622745561904-a6bb741c-5c3a").find_all("tr")
table_2 = root.find("div", class_="vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, 26):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Colombia_2021.csv", index=False)

# %% [markdown]
# Colombia 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/colombia-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Colombia_2022.csv", index=False)

# %% [markdown]
# Costa Rica 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1526076948182-07ca7f31-0de3").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2014.csv", index=False)

# %% [markdown]
# Costa Rica 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2015.csv", index=False)

# %% [markdown]
# Costa Rica 2016

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2016/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2016.csv", index=False)

# %% [markdown]
# Costa Rica 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-coe-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2017.csv", index=False)

# %% [markdown]
# Costa Rica 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1531250816282-0558c1c2-6855").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2018.csv", index=False)

# %% [markdown]
# Costa Rica 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    # col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2019.csv", index=False)

# %% [markdown]
# Costa Rica 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/costa-rica-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Costa_Rica_2020.csv", index=False)

# %% [markdown]
# Costa Rica 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1627584535420-dcd6bd18-6a85").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, 34):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Costa_Rica_2021.csv", index=False)

# %% [markdown]
# Costa Rica 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Costa_Rica_2022.csv", index=False)

# %% [markdown]
# Costa Rica 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/costa-rica-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Costa_Rica_2023.csv", index=False)

# %% [markdown]
# Ecuador 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/ecuador-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find_all("div", class_="vc_tta-panel")[1].find_all("tr")


col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Ecuador_2021.csv", index=False)

# %% [markdown]
# Ecuador 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/ecuador-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find_all("div", class_="vc_tta-panel")[1].find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    if i != 2:
        tmp = table[i].find_all("td")
        # tmp_2 = table_2[i].find_all("td")
        col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
        col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
        col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
        # farm_url.append(tmp[1].find("a").get("href"))
        col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
        col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
        col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
        col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())
    else:
        print("skip")

for i in range(1, 23):
    try:
        tmp_2 = table_2[i].find_all("td")
        # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
        farm_url.append(tmp_2[2].find("a").get("href"))
        print(i)
    except IndexError:
        print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Ecuador_2022.csv", index=False)

# %% [markdown]
# El Salvador 2013

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2013/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2013.csv", index=False)

# %% [markdown]
# El Salvador 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2014.csv", index=False)

# %% [markdown]
# El Salvador 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2015.csv", index=False)

# %% [markdown]
# El Salvador 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2017.csv", index=False)

# %% [markdown]
# El Salvador 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2018.csv", index=False)

# %% [markdown]
# El Salvador 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El_Salvador_2019.csv", index=False)

# %% [markdown]
# El Salvador 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/el-salvador-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("El Salvador_2020.csv", index=False)

# %% [markdown]
# El Salvador 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1628622572304-1f957969-c725").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text)
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text)
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text)
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text)
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text)


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("El Salvador_2021.csv", index=False)

# %% [markdown]
# El Salvador 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text)
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text)
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text)
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text)
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text)


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("El Salvador_2022.csv", index=False)

# %% [markdown]
# El Salvador 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/el-salvador-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[2].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("El Salvador_2023.csv", index=False)

# %% [markdown]
# Ethiopia 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/ethiopia-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/ethiopia-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    # col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Ethiopia_2020.csv", index=False)

# %% [markdown]
# Ethiopia 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/ethiopia-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find_all("div", class_="vc_tta-panel")[1].find_all("tr")


col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Ethiopia_2021.csv", index=False)

# %% [markdown]
# Ethiopia 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/ethiopia-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find_all("div", class_="vc_tta-panel")[1].find_all("tr")


col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].text.strip())
    col_dict['high_bid'].append(tmp[4].text.strip())
    col_dict['total_value'].append(tmp[5].text.strip())
    col_dict['company'].append(tmp[6].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Ethiopia_2022.csv", index=False)

# %% [markdown]
# Guatemala 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df.to_csv("Guatemala_2014.csv", index=False)

# %% [markdown]
# Guatemala 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2015.csv", index=False)

# %% [markdown]
# Guatemala 2016

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2016/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2016.csv", index=False)

# %% [markdown]
# Guatemala 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2017.csv", index=False)

# %% [markdown]
# Guatemala 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1531857963442-ae3689ed-1058").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2018.csv", index=False)

# %% [markdown]
# Guatemala 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    print(farm_url)
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    try:
        all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
        all_cat = [cat.text.strip() for cat in all_cat]
        all_info = farm_root.find("div", id="listing-details").find_all("td")
    except AttributeError:
        all_cat = []
        all_info = []
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2019.csv", index=False)

# %% [markdown]
# Guatemala 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/guatemala-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Guatemala_2020.csv", index=False)

# %% [markdown]
# Guatemala 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1627412232389-b13030fa-3598").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Guatemala_2021.csv", index=False)

# %% [markdown]
# Guatemala 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Guatemala_2022.csv", index=False)

# %% [markdown]
# Guatemala 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/guatemala-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[2].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Guatemala_2023.csv", index=False)

# %% [markdown]
# Honduras 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2014.csv", index=False)

# %% [markdown]
# Honduras 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2015.csv", index=False)

# %% [markdown]
# Honduras 2016

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2016/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2016.csv", index=False)

# %% [markdown]
# Honduras 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2017.csv", index=False)

# %% [markdown]
# Honduras 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1530640853508-b3f53acd-4dd3").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(0, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i+1].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2018.csv", index=False)

# %% [markdown]
# Honduras 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    # col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Honduras_2019.csv", index=False)

# %% [markdown]
# Honduras 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1629394188014-95319fde-2a4c").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Honduras_2021.csv", index=False)

# %% [markdown]
# Honduras 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Honduras_2022.csv", index=False)

# %% [markdown]
# Honduras 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/honduras-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Honduras_2023.csv", index=False)

# %% [markdown]
# Indonesia 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/indonesia-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1643312940613-53cf472d-7577").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

col_dict['Processing System'] = []

for i in range(1, len(table)-1):
    # tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['Processing System'].append(tmp_2[7].find("div", class_="mtr-cell-content").text.strip())
df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df
# Out:
#    rank coe_score                           farm weight_(lbs.) high_bid  \
# 0     1     89.28                  Pantan Musara        462.97   $80.00
# 1     2     89.04                       Ibun Ita        410.06   $65.20
# 2     3     88.89                  Pantan Musara        577.61   $69.10
# 3     4     88.75                   Ijen Lestari        791.46   $35.20
# 4     5     88.58                      Ibun Yudi        454.15   $25.10
# 5     6     88.49     Koperasi Koerintji Barokah        454.15   $21.70
# 6     7     88.46                   Avatara Gayo        480.61   $45.20
# 7     8      88.3                       Kamojang        447.54   $19.20
# 8     9     88.25                         Topidi        416.67   $24.30
# 9    10     88.15  Lereng Gunung Argopuro Krucil         427.7   $24.20
# 10   11     88.14                         Topidi        462.97   $18.60
# 11   12     88.05          PT Sulotco Jaya Abadi        462.97   $19.30
# ...

# %%
df.to_csv("Indonesia_2021.csv", index=False)

# %% [markdown]
# Indonesia 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/indonesia-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1643312940613-53cf472d-7577").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Indonesia_2022.csv", index=False)

# %% [markdown]
# Mexico 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("México_2014.csv", index=False)

# %% [markdown]
# México 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("México_2015.csv", index=False)

# %% [markdown]
# Honduras 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("México_2017.csv", index=False)

# %% [markdown]
# México 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1532451068017-63a2021a-1ec4").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("México_2018.csv", index=False)

# %% [markdown]
# México 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    # col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("México_2019.csv", index=False)

# %% [markdown]
# México 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("México_2021.csv", index=False)

# %% [markdown]
# México 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Mexico_2022.csv", index=False)

# %% [markdown]
# Mexico 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/mexico-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Mexico_2023.csv", index=False)

# %% [markdown]
# Nicaragua 2012

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2012/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2012.csv", index=False)

# %% [markdown]
# Nicaragua 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2014.csv", index=False)

# %% [markdown]
# Nicaragua 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2015.csv", index=False)

# %% [markdown]
# Nicaragua 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2017.csv", index=False)

# %% [markdown]
# Nicaragua 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1528908045253-ec3b05af-fd97").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2018.csv", index=False)

# %% [markdown]
# Costa Rica 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/nicaragua-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Nicaragua_2020.csv", index=False)

# %% [markdown]
# Nicaragua 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1624987513588-1d33e9a4-0462").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

# for i in range(1, 34):
#     tmp_2 = table_2[i].find_all("td")
#     # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
#     farm_url.append(tmp_2[2].find("a").get("href"))
#     # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Nicaragua_2021.csv", index=False)

# %% [markdown]
# Nicaragua 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Nicaragua_2022.csv", index=False)

# %% [markdown]
# Nicaragua 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/nicaragua-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    print(farm_url)
    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    try:
        lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    except IndexError:
        lot_information = all_info[1].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df

# %%
df.to_csv("Nicaragua_2023.csv", index=False)

# %% [markdown]
# Rwanda 2008

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2008/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Rwanda_2008.csv", index=False)

# %% [markdown]
# Rwanda 2010

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2010/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df

# %%
df.to_csv("Rwanda_2010.csv", index=False)

# %% [markdown]
# Rwanda 2011

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2011/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2011.csv", index=False)

# %% [markdown]
# Rwanda 2012

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2012/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2012.csv", index=False)

# %% [markdown]
# Rwanda 2013

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2013/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2013.csv", index=False)

# %% [markdown]
# Rwanda 2014

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2014/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1534547218046-126e15f4-4b38").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2014.csv", index=False)

# %% [markdown]
# Rwanda 2015

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2015/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2015.csv", index=False)

# %% [markdown]
# Rwanda 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/rwanda-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1537037365523-22d0cfdf-14ae").find_all("tr")
table_2 = root.find("table", class_="table").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    # print(i)
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].text.strip())
    col_dict['coe_score'].append(tmp_2[5].text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Rwanda_2018.csv", index=False)

# %% [markdown]
# Perú 2017

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2017/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1513038059038-106d1cd7-3c49").find_all("tr")
table_2 = root.find("table", class_="table mtr-table mtr-thead-th").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df

# %%
df.to_csv("Peru_2017.csv", index=False)

# %% [markdown]
# Peru 2018

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2018/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1538505057050-ed3488f6-00d5").find_all("tr")
table_2 = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Other", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp_2[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text)
    col_dict['high_bid'].append(tmp[3].text.strip())
    col_dict['total_value'].append(tmp[4].text.strip())
    col_dict['company'].append(tmp[5].text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Other": "Coffee Characteristics"})

# %%
df
# Out:
#    rank coe_score                                farm weight_(lbs.)  \
# 0    1a     91.08              Dwigth Aguilkar Masias           NaN
# 1    1b     91.08              Dwigth Aguilkar Masias           NaN
# 2     2     89.85              Damian Espinoza Garcia           NaN
# 3     3     89.58           Franklin Chinguel Morales           NaN
# 4     4     89.43            Florencia Mamani Calcina           NaN
# 5     5     89.28       Eleuterio Bolaños Torrecillas           NaN
# 6     6     89.20                Roxana Rangel Granda           NaN
# 7     7     88.65         Elvis Reinerio Tineo Rafael           NaN
# 8     8     88.45    Jesus Pilar Mijahuanca Rodriguez           NaN
# 9     9     88.23        Frank Gurvich Garcia Pariona           NaN
# 10   10     88.20                Fredy Bermeo Guevara           NaN
# 11   11     87.62              Delia Capquique Quispe           NaN
# 12   12     87.48            Alejandro Diaz Goicochea           NaN
# ...

# %%
df.to_csv("Peru_2018.csv", index=False)

# %% [markdown]
# Perú 2019

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2019/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1527620169107-6a0042a0-7c06").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Coffee Characteristics", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    # col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())


score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

for i in range(1, len(score_table)):
    tmp = score_table[i].find_all("td")
    col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df
# Out:
#    rank coe_score                        farm weight_(lbs.)   high_bid  \
# 0    1a     92.28                   La Lucuma        396.83  $20.00/lb
# 1    1b     92.28                   La Lucuma        423.29  $19.80/lb
# 2    2a     91.44              Nuevo Progreso        396.83  $30.00/lb
# 3    2b     91.44              Nuevo Progreso        394.63  $30.00/lb
# 4    3a     91.40                  Agua Dulce        462.97  $12.60/lb
# 5    3b     91.40                  Agua Dulce        449.74  $12.50/lb
# 6     4     90.88                   Romerillo        723.34  $16.00/lb
# 7     5     90.47                  Perla Mayo       1168.45   $8.90/lb
# 8     6     90.29                 Santa Sofia        884.05   $8.70/lb
# 9     7     89.69                   Monte Rey       1110.03   $8.60/lb
# 10    8     89.32                     Morales        814.61   $8.40/lb
# 11    9     89.18               Nueva Alianza        839.08  $16.88/lb
# ...

# %%
df.to_csv("Peru_2019.csv", index=False)

# %% [markdown]
# Perú 2020

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2020/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

url_2 = "https://cupofexcellence.org/peru-2020/"
page_2 = requests.get(url_2)
root_2 = BeautifulSoup(page_2.content, 'html.parser')

table_2 = root_2.find("table", class_="mtr-table mtr-tr-td").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer/Rep.", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma/Flavor", "Acidity", "Processing system", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table_2)):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_cat = farm_root.find("div", id="listing-details").find("tbody").find_all("th")
    all_cat = [cat.text.strip() for cat in all_cat]
    all_info = farm_root.find("div", id="listing-details").find_all("td")
    
    for key in col_name[7:]:
        index = check_in_category(all_cat, key)
        if index != -1:
            col_dict[key].append(all_info[index].text)
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])
    
df = pd.DataFrame(col_dict)

# df = pd.DataFrame({col_name[0]:rank, col_name[1]:score ,col_name[2]:farm, col_name[3]:weight, col_name[4]:high_bid, col_name[5]:total_value, col_name[6]:company, col_name[7]:rank_1, col_name[8]:farm_1, col_name[9]:farmer, col_name[10]:altitude, col_name[11]:country, col_name[12]:year, col_name[13]:city, col_name[14]:region, col_name[15]:program, col_name[16]:cof_characteristics, col_name[17]:aroma, col_name[18]:acidity, col_name[19]:process, col_name[20]:variety, col_name[21]:cof_grow_area, col_name[22]:farm_size})

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics"})

# %%
df
# Out:
#    rank coe_score                farm weight_(lbs.) high_bid total_value  \
# 0    1a        90           Esperanza        442.85   $51.10  $22,629.64
# 1    1b        90           Esperanza         396.9   $50.70  $20,122.83
# 2     2     89.58     Caminos El Inca        482.34   $28.70  $13,843.16
# 3     3     88.96           El Laurel        683.44   $17.10  $11,686.82
# 4     4     88.92        La Esperanza        583.51   $17.50  $10,211.43
# 5     5     88.88  Bella Siempre Viva        630.87   $23.10  $14,573.10
# 6     6     88.77          Agua Dulce        843.85   $16.10  $13,585.99
# 7     7     88.77             O´Sopen        549.46   $16.00   $8,791.36
# 8     8     88.73            La Palma        835.96   $26.00  $21,734.96
# 9     9     88.58         Buena Vista        626.51   $16.30  $10,212.11
# 10   10     88.58       Nueva Alianza        700.62   $29.40  $20,598.23
# 11   11     88.54             El Rejo        859.95   $12.70  $10,921.37
# ...

# %%
df.to_csv("Peru_2020.csv", index=False)

# %% [markdown]
# Perú 2021

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2021/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1639503437664-94ee004b-c3f8").find_all("tr")
table_2 = root.find("div", "vc_tta-container").find_all("tr")

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    # tmp_2 = table_2[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    # farm_url.append(tmp[1].find("a").get("href"))
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())

for i in range(1, len(table)-1):
    tmp_2 = table_2[i].find_all("td")
    # col_dict['coe_score'].append(tmp_2[5].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp_2[2].find("a").get("href"))
    # print(i)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df
# Out:
#    rank coe_score                    farm weight_(lbs.) high_bid total_value  \
# 0    1a      90.2           Nueva Alianza        330.69   $54.60  $18,055.67
# 1    1b      90.2           Nueva Alianza        352.08   $50.40  $17,744.83
# 2    2a     90.08            Santa Mónica        330.69   $34.30  $11,342.67
# 3    2b     90.08            Santa Mónica        340.61   $33.50  $11,410.44
# 4    3a        90                La Palta        264.55   $27.60   $7,301.58
# 5    3b        90                La Palta        297.62   $27.70   $8,244.07
# 6     4     89.38               Chiriloma        610.68   $25.70  $15,694.48
# 7     5     89.09            Santa Teresa      1,640.96   $14.00  $22,973.44
# 8     6     89.06             Carmen Alto        593.92   $23.20  $13,778.94
# 9     7     88.97          Nuevo Progreso        595.25   $20.00  $11,905.00
# 10    8     88.38           La Candelaria        626.55   $26.00  $16,290.30
# ...

# %%
df.to_csv("Peru_2021.csv", index=False)

# %% [markdown]
# Peru 2022

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2022/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[1].find("a").get("href"))
    col_dict['coe_score'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df
# Out:
#    rank coe_score                          farm weight_(lbs.) high_bid  \
# 0    1a     90.39                       LA BOLA        363,76   $75.00
# 1    1b     90.39                       LA BOLA        264,55   $78.50
# 2    2a     90.25                 SAN SEBASTIAN        381,66   $30.40
# 3    2b     90.25                 SAN SEBASTIAN        264,55   $30.30
# 4    3a        90                      EL CERRO        306,13   $30.10
# 5    3b        90                      EL CERRO        264,55   $31.50
# 6     4      89.8                     CHIRILOMA        595,25   $15.90
# 7     5     89.66              FUNDO PUQUIOPATA        584,82   $13.70
# 8     6     89.46               BELLO HORIZONTE        637,25   $20.20
# 9     7      89.3                ALTO MORERILLO        591,79   $12.00
# 10    8     89.02                NUEVO PROGRESO        631,78   $20.20
# 11    9     88.89                     SILLAPATA        595,25   $15.60
# ...

# %%
df.to_csv("Peru_2022.csv", index=False)

# %% [markdown]
# Peru 2023

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL of the page we want to scrape
url = 'https://allianceforcoffeeexcellence.org/peru-2023/'

# Get the page contents
page = requests.get(url)
root = BeautifulSoup(page.content, 'html.parser')

table = root.find("div", class_="vc_tta-panel", id="1626373223108-e0a94038-d157").find_all("tr")

table[0]

col_name = ["rank", "coe_score" ,"farm", "weight_(lbs.)", "high_bid", "total_value","company", "Farmer", "Altitude", "Country", "Year", "City",	
            "Region", "Overall", "Aroma / Flavor", "Acidity", "Processing System", "Variety", "Coffee Growing Area", "Farm Size"]

col_dict = {name: [] for name in col_name}
farm_url = []

for i in range(1, len(table)-1):
    tmp = table[i].find_all("td")
    col_dict['rank'].append(tmp[0].find("div", class_="mtr-cell-content").text.strip())
    col_dict['farm'].append(tmp[2].find("div", class_="mtr-cell-content").text.strip())
    farm_url.append(tmp[2].find("a").get("href"))
    col_dict['coe_score'].append(tmp[1].find("div", class_="mtr-cell-content").text.strip())
    col_dict['weight_(lbs.)'].append(tmp[3].find("div", class_="mtr-cell-content").text.strip())
    col_dict['high_bid'].append(tmp[4].find("div", class_="mtr-cell-content").text.strip())
    col_dict['total_value'].append(tmp[5].find("div", class_="mtr-cell-content").text.strip())
    col_dict['company'].append(tmp[6].find("div", class_="mtr-cell-content").text.strip())


# score_table = root.find("div", class_="vc_tta-container").find("tbody").find_all("tr")

# for i in range(1, len(score_table)):
#     tmp = score_table[i].find_all("td")
#     col_dict['coe_score'].append(tmp[5].find("div", class_="mtr-cell-content").text)

# %%
farm_info_cat = ['Farmer', 'Altitude', 'Farm Size']
Lot_info_cat = ['Year', "Processing System", "Variety", "Overall", "Aroma / Flavor", "Acidity"]

# %%
for farm_url in farm_url:
    farm_page = requests.get(farm_url)
    farm_root = BeautifulSoup(farm_page.content, 'html.parser')
    all_info = farm_root.find_all("div", class_="element table-block")

    ## farm_information
    fram_information = all_info[0].find("div", class_="pf-body").find_all("li")
    farm_cat = [cat.find("div", class_="item-attr").text.strip() for cat in fram_information]
    for key in farm_info_cat:
        index = check_in_category(farm_cat, key)
        if index != -1:
            col_dict[key].append(fram_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")
    
    ## Lot Information
    lot_information = all_info[2].find("div", class_="pf-body").find_all("li")
    lot_cat = [cat.find("div", class_="item-attr").text.strip() for cat in lot_information]

    for key in Lot_info_cat:
        index = check_in_category(lot_cat, key)
        if index != -1:
            col_dict[key].append(lot_information[index].find("div", class_="item-property").text.strip())
        else:
            col_dict[key].append("NaN")

for key in col_dict:
    if not col_dict[key]:
        col_dict[key] = ["NaN"] * len(col_dict['rank'])

df = pd.DataFrame(col_dict)

# %%
df = df.rename(columns={"Overall": "Coffee Characteristics",
                        "Processing System": "Processing system",
                        "Aroma / Flavor": "Aroma/Flavor",
                        "Farmer": "Farmer/Rep."})

# %%
df
# Out:
#    rank coe_score                farm weight_(lbs.) high_bid total_value  \
# 0    1a     90.74        Alto Mirador        330.69   $80.20  $26,521.34
# 1    1b     90.74        Alto Mirador        327.54   $80.30  $26,301.46
# 2    2a     90.68           La Lucuma        396.83   $44.80  $17,777.98
# 3    2b     90.68           La Lucuma        388.76   $44.10  $17,144.32
# 4    3a     90.32           Chiriloma        330.69   $60.10  $19,874.47
# 5    3b     90.32           Chiriloma        286.60   $62.55  $17,926.83
# 6     4     90.15            Pedregal        595.25   $25.40  $15,119.35
# 7     5     89.62               Randu        586.58   $19.00  $11,145.02
# 8     6     89.47          Llactapata        635.37   $23.00  $14,613.51
# 9     7     89.41             El Pino       1124.36   $18.00  $20,238.48
# 10    8     89.29     Bello Horizonte        767.55   $24.00  $18,421.20
# 11    9     89.24       Nueva Alianza        650.36   $21.95  $14,275.40
# ...

# %%
df.to_csv("Peru_2023.csv", index=False)
